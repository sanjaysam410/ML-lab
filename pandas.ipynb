# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 2.2.2

# %%
df=pd.read_csv("marks.csv")

# %%
df.head()
# Out:
#    Rno                          Name    CD  DAA    ML  CNS  PE-II  SSIS
# 0    1  VANKAYALA BALA SURYA KRISHNA  14.0   20  17.0    7     20    14
# 1    2    SANKARAMADDI HEMANTH REDDY  15.0   19  17.0   15     17    16
# 2    3                ADEPU SHASHANK  10.3   12  10.0    2     11     7
# 3    4                  NARRA VARSHA  12.0   17  10.3   17     20    19
# 4    5    JONNALAGADDA MARUTHI TEJAS  12.0   20  16.0   13     10    12

# %%
df.tail()
# Out:
#     Rno               Name    CD  DAA    ML  CNS  PE-II  SSIS
# 61   62      THOTA CHANDAN   8.0    7   8.0    9      7     8
# 62   63     NAGALLA LOHITH   9.0    9   9.0   12      8    10
# 63   64  GANAM GIRI PRASAD  12.0   12  12.0   12     14    13
# 64   65         MOHD OSMAN   7.0   10   9.0    9      9     9
# 65   66     KATHERA VAMSHI   8.0   12  10.0   12      4     8

# %%
df.describe()
# Out:
#              Rno         CD        DAA         ML        CNS      PE-II  \
# count  66.000000  66.000000  66.000000  66.000000  66.000000  66.000000
# mean   33.500000  11.731818  11.863636  11.837879  11.530303  11.727273
# std    19.196354   3.547791   4.238601   3.646189   3.742561   4.579370
# min     1.000000   3.000000   0.000000   3.000000   1.000000   0.000000
# 25%    17.250000   9.000000   9.000000  10.000000  10.000000   9.000000
# 50%    33.500000  12.000000  12.000000  12.000000  12.000000  12.000000
# 75%    49.750000  15.000000  15.000000  15.000000  14.000000  15.000000
# max    66.000000  19.000000  20.000000  18.000000  19.000000  20.000000
#
#             SSIS
# count  66.000000
# mean   11.590909
# std     4.064773
# min     2.000000
# 25%     9.000000
# 50%    12.500000
# 75%    14.000000
# max    20.000000

# %%
df.shape
# Out:
# (66, 8)

# %%
df["Name"]
# Out:
# 0     VANKAYALA BALA SURYA KRISHNA
# 1       SANKARAMADDI HEMANTH REDDY
# 2                   ADEPU SHASHANK
# 3                     NARRA VARSHA
# 4       JONNALAGADDA MARUTHI TEJAS
#                   ...
# 61                   THOTA CHANDAN
# 62                  NAGALLA LOHITH
# 63               GANAM GIRI PRASAD
# 64                      MOHD OSMAN
# 65                  KATHERA VAMSHI
# Name: Name, Length: 66, dtype: object

# %%
df[["Name","CD","ML"]].head(10)
# Out:
#                                    Name    CD    ML
# 0          VANKAYALA BALA SURYA KRISHNA  14.0  17.0
# 1            SANKARAMADDI HEMANTH REDDY  15.0  17.0
# 2                        ADEPU SHASHANK  10.3  10.0
# 3                          NARRA VARSHA  12.0  10.3
# 4            JONNALAGADDA MARUTHI TEJAS  12.0  16.0
# 5                        AYENDLA SOWMYA  12.0  12.0
# 6                JAJAPURAM SAI CHANDANA  16.0  18.0
# 7  BURELA DAKSHAYANI LAKSHMI SARASWATHI  12.0  11.0
# 8                             CH ANEESH   9.0  12.0
# 9                  PABBA VAMSHI KRISHNA  13.0  16.0

# %%
df.iterrows()
for rec in df.iterrows():
    print(rec)
# Out:
# (0, Rno                                 1
# Name     VANKAYALA BALA SURYA KRISHNA
# CD                               14.0
# DAA                                20
# ML                               17.0
# CNS                                 7
# PE-II                              20
# SSIS                               14
# Name: 0, dtype: object)
# (1, Rno                               2
# Name     SANKARAMADDI HEMANTH REDDY
# CD                             15.0
# DAA                              19
# ML                             17.0
# CNS                              15
# PE-II                            17
# SSIS                             16
# Name: 1, dtype: object)
# (2, Rno                   3
# Name     ADEPU SHASHANK
# CD                 10.3
# DAA                  12
# ML                 10.0
# CNS                   2
# PE-II                11
# SSIS                  7
# Name: 2, dtype: object)
# (3, Rno                 4
# Name     NARRA VARSHA
# CD               12.0
# ...

# %%
df.loc[0:2]
# Out:
#    Rno                          Name    CD  DAA    ML  CNS  PE-II  SSIS
# 0    1  VANKAYALA BALA SURYA KRISHNA  14.0   20  17.0    7     20    14
# 1    2    SANKARAMADDI HEMANTH REDDY  15.0   19  17.0   15     17    16
# 2    3                ADEPU SHASHANK  10.3   12  10.0    2     11     7

# %%
df.iloc[0:2]
# Out:
#    Rno                          Name    CD  DAA    ML  CNS  PE-II  SSIS
# 0    1  VANKAYALA BALA SURYA KRISHNA  14.0   20  17.0    7     20    14
# 1    2    SANKARAMADDI HEMANTH REDDY  15.0   19  17.0   15     17    16

# %%
df.loc[0:2,["Name","DAA"]]
# Out:
#                            Name  DAA
# 0  VANKAYALA BALA SURYA KRISHNA   20
# 1    SANKARAMADDI HEMANTH REDDY   19
# 2                ADEPU SHASHANK   12

# %%
df.iloc[0:2,[1,3]]
# Out:
#                            Name  DAA
# 0  VANKAYALA BALA SURYA KRISHNA   20
# 1    SANKARAMADDI HEMANTH REDDY   19

# %%
df.sort_values("ML")
# Out:
#     Rno                          Name    CD  DAA    ML  CNS  PE-II  SSIS
# 47   48       MOHAMMED ZAKI UR RAHMAN   5.0    0   3.0    7     14    11
# 42   43                   MAJIGE ARUN   3.0    5   4.0   14     10    14
# 52   53       VELPULA ABHINOV SIDDHIQ  10.0    9   5.0   13     12    13
# 23   24              MADIREDDY YAMINI   6.0    6   6.0   10      5     8
# 53   54       SUDA LAKSHMI MANI KUMAR   6.0    6   6.0   10      5     3
# ..  ...                           ...   ...  ...   ...  ...    ...   ...
# 1     2    SANKARAMADDI HEMANTH REDDY  15.0   19  17.0   15     17    16
# 33   34              BAYYARAM MAANASA  19.0   15  17.0   12     14    13
# 18   19                BALNE THRINATH  18.0   16  17.0   15     16    16
# 0     1  VANKAYALA BALA SURYA KRISHNA  14.0   20  17.0    7     20    14
# 6     7        JAJAPURAM SAI CHANDANA  16.0   20  18.0   10     10     8
#
# [66 rows x 8 columns]

# %%
df.sort_values("ML",ascending=False)
# Out:
#     Rno                          Name    CD  DAA    ML  CNS  PE-II  SSIS
# 6     7        JAJAPURAM SAI CHANDANA  16.0   20  18.0   10     10     8
# 0     1  VANKAYALA BALA SURYA KRISHNA  14.0   20  17.0    7     20    14
# 1     2    SANKARAMADDI HEMANTH REDDY  15.0   19  17.0   15     17    16
# 18   19                BALNE THRINATH  18.0   16  17.0   15     16    16
# 33   34              BAYYARAM MAANASA  19.0   15  17.0   12     14    13
# ..  ...                           ...   ...  ...   ...  ...    ...   ...
# 26   27       STOTHRA BHASHYAM SRIRAM   7.0    4   6.0    1      9     5
# 53   54       SUDA LAKSHMI MANI KUMAR   6.0    6   6.0   10      5     3
# 52   53       VELPULA ABHINOV SIDDHIQ  10.0    9   5.0   13     12    13
# 42   43                   MAJIGE ARUN   3.0    5   4.0   14     10    14
# 47   48       MOHAMMED ZAKI UR RAHMAN   5.0    0   3.0    7     14    11
#
# [66 rows x 8 columns]

# %%
df.sort_values(["ML","Name"])
# Out:
#     Rno                          Name    CD  DAA    ML  CNS  PE-II  SSIS
# 47   48       MOHAMMED ZAKI UR RAHMAN   5.0    0   3.0    7     14    11
# 42   43                   MAJIGE ARUN   3.0    5   4.0   14     10    14
# 52   53       VELPULA ABHINOV SIDDHIQ  10.0    9   5.0   13     12    13
# 23   24              MADIREDDY YAMINI   6.0    6   6.0   10      5     8
# 26   27       STOTHRA BHASHYAM SRIRAM   7.0    4   6.0    1      9     5
# ..  ...                           ...   ...  ...   ...  ...    ...   ...
# 18   19                BALNE THRINATH  18.0   16  17.0   15     16    16
# 33   34              BAYYARAM MAANASA  19.0   15  17.0   12     14    13
# 1     2    SANKARAMADDI HEMANTH REDDY  15.0   19  17.0   15     17    16
# 0     1  VANKAYALA BALA SURYA KRISHNA  14.0   20  17.0    7     20    14
# 6     7        JAJAPURAM SAI CHANDANA  16.0   20  18.0   10     10     8
#
# [66 rows x 8 columns]

# %%
df.sort_values(["Name","ML"])
# Out:
#     Rno                          Name    CD  DAA    ML  CNS  PE-II  SSIS
# 2     3                ADEPU SHASHANK  10.3   12  10.0    2     11     7
# 10   11                  ARJUN SHARMA   9.0   13  11.0   15     12    14
# 5     6                AYENDLA SOWMYA  12.0   12  12.0   10     18    15
# 17   18                   B VAISHNAVI  12.0   12  12.0    5      5     5
# 18   19                BALNE THRINATH  18.0   16  17.0   15     16    16
# ..  ...                           ...   ...  ...   ...  ...    ...   ...
# 16   17                     V SAI RAM   8.0    5   7.0   15     15    15
# 25   26     VADLA HARSHAVARDHAN CHARY  15.0   17  16.0   14     15    15
# 0     1  VANKAYALA BALA SURYA KRISHNA  14.0   20  17.0    7     20    14
# 21   22          VASPARI THARUN KUMAR  15.0   12  14.0   14     14    14
# 52   53       VELPULA ABHINOV SIDDHIQ  10.0    9   5.0   13     12    13
#
# [66 rows x 8 columns]

# %%
df["Total"]=0

# %%
df.head(2)
# Out:
#    Rno                          Name    CD  DAA    ML  CNS  PE-II  SSIS
# 0    1  VANKAYALA BALA SURYA KRISHNA  14.0   20  17.0    7     20    14
# 1    2    SANKARAMADDI HEMANTH REDDY  15.0   19  17.0   15     17    16

# %%
df.info
# Out:
# <bound method DataFrame.info of     Rno                          Name    CD  DAA    ML  CNS  PE-II  SSIS  \
# 0     1  VANKAYALA BALA SURYA KRISHNA  14.0   20  17.0    7     20    14
# 1     2    SANKARAMADDI HEMANTH REDDY  15.0   19  17.0   15     17    16
# 2     3                ADEPU SHASHANK  10.3   12  10.0    2     11     7
# 3     4                  NARRA VARSHA  12.0   17  10.3   17     20    19
# 4     5    JONNALAGADDA MARUTHI TEJAS  12.0   20  16.0   13     10    12
# ..  ...                           ...   ...  ...   ...  ...    ...   ...
# 61   62                 THOTA CHANDAN   8.0    7   8.0    9      7     8
# 62   63                NAGALLA LOHITH   9.0    9   9.0   12      8    10
# 63   64             GANAM GIRI PRASAD  12.0   12  12.0   12     14    13
# 64   65                    MOHD OSMAN   7.0   10   9.0    9      9     9
# 65   66                KATHERA VAMSHI   8.0   12  10.0   12      4     8
#
#     Total
# 0       0
# 1       0
# 2       0
# 3       0
# ...

# %%
df
# Out:
#     Rno                          Name    CD  DAA    ML  CNS  PE-II  SSIS  \
# 0     1  VANKAYALA BALA SURYA KRISHNA  14.0   20  17.0    7     20    14
# 1     2    SANKARAMADDI HEMANTH REDDY  15.0   19  17.0   15     17    16
# 2     3                ADEPU SHASHANK  10.3   12  10.0    2     11     7
# 3     4                  NARRA VARSHA  12.0   17  10.3   17     20    19
# 4     5    JONNALAGADDA MARUTHI TEJAS  12.0   20  16.0   13     10    12
# ..  ...                           ...   ...  ...   ...  ...    ...   ...
# 61   62                 THOTA CHANDAN   8.0    7   8.0    9      7     8
# 62   63                NAGALLA LOHITH   9.0    9   9.0   12      8    10
# 63   64             GANAM GIRI PRASAD  12.0   12  12.0   12     14    13
# 64   65                    MOHD OSMAN   7.0   10   9.0    9      9     9
# 65   66                KATHERA VAMSHI   8.0   12  10.0   12      4     8
#
#     Total
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
# ..    ...
# ...

# %%
df["Total"]=df["CD"]+df["DAA"]+df["ML"]+df["CNS"]+df["PE-II"]+df["SSIS"]

# %%
df.head()
# Out:
#    Rno                          Name    CD  DAA    ML  CNS  PE-II  SSIS  Total
# 0    1  VANKAYALA BALA SURYA KRISHNA  14.0   20  17.0    7     20    14   92.0
# 1    2    SANKARAMADDI HEMANTH REDDY  15.0   19  17.0   15     17    16   99.0
# 2    3                ADEPU SHASHANK  10.3   12  10.0    2     11     7   52.3
# 3    4                  NARRA VARSHA  12.0   17  10.3   17     20    19   95.3
# 4    5    JONNALAGADDA MARUTHI TEJAS  12.0   20  16.0   13     10    12   83.0

# %%
df.info
# Out:
# <bound method DataFrame.info of     Rno                          Name    CD  DAA    ML  CNS  PE-II  SSIS  \
# 0     1  VANKAYALA BALA SURYA KRISHNA  14.0   20  17.0    7     20    14
# 1     2    SANKARAMADDI HEMANTH REDDY  15.0   19  17.0   15     17    16
# 2     3                ADEPU SHASHANK  10.3   12  10.0    2     11     7
# 3     4                  NARRA VARSHA  12.0   17  10.3   17     20    19
# 4     5    JONNALAGADDA MARUTHI TEJAS  12.0   20  16.0   13     10    12
# ..  ...                           ...   ...  ...   ...  ...    ...   ...
# 61   62                 THOTA CHANDAN   8.0    7   8.0    9      7     8
# 62   63                NAGALLA LOHITH   9.0    9   9.0   12      8    10
# 63   64             GANAM GIRI PRASAD  12.0   12  12.0   12     14    13
# 64   65                    MOHD OSMAN   7.0   10   9.0    9      9     9
# 65   66                KATHERA VAMSHI   8.0   12  10.0   12      4     8
#
#     Total
# 0    92.0
# 1    99.0
# 2    52.3
# 3    95.3
# ...

# %%
df.loc[df["DAA"]>9]
# Out:
#     Rno                          Name    CD  DAA    ML  CNS  PE-II  SSIS  \
# 0     1  VANKAYALA BALA SURYA KRISHNA  14.0   20  17.0    7     20    14
# 1     2    SANKARAMADDI HEMANTH REDDY  15.0   19  17.0   15     17    16
# 2     3                ADEPU SHASHANK  10.3   12  10.0    2     11     7
# 3     4                  NARRA VARSHA  12.0   17  10.3   17     20    19
# 4     5    JONNALAGADDA MARUTHI TEJAS  12.0   20  16.0   13     10    12
# 5     6                AYENDLA SOWMYA  12.0   12  12.0   10     18    15
# 6     7        JAJAPURAM SAI CHANDANA  16.0   20  18.0   10     10     8
# 8     9                     CH ANEESH   9.0   15  12.0   16     12    10
# 9    10          PABBA VAMSHI KRISHNA  13.0   19  16.0   14     14    14
# 10   11                  ARJUN SHARMA   9.0   13  11.0   15     12    14
# 12   13               GOGULA NAVATEJA  16.0   14  15.0   12     19    16
# 13   14           MADAM VEDANTH V N N  15.0   16  16.0   11     15    13
# ...

# %%
df.loc[df["Name"].str.startswith('S')]
# Out:
#     Rno                        Name    CD  DAA    ML  CNS  PE-II  SSIS  Total
# 1     2  SANKARAMADDI HEMANTH REDDY  15.0   19  17.0   15     17    16   99.0
# 11   12           SARIKONDA LEKHANA  15.0    8  12.0    9     14    12   70.0
# 20   21            SAI ASHRIT PINNI   6.0    7   7.0   12     10    11   53.0
# 26   27     STOTHRA BHASHYAM SRIRAM   7.0    4   6.0    1      9     5   32.0
# 27   28              SHEFALI THAKUR  14.0   16  15.0   16     16    16   93.0
# 29   30             SYED ZAQIULLAH   10.0   10  10.0   10     10    10   60.0
# 34   35           SHENIGARAM SREEJA  15.0   17  16.0   19     19    19  105.0
# 53   54     SUDA LAKSHMI MANI KUMAR   6.0    6   6.0   10      5     3   36.0
# 60   61                SIMPI SUDEEP  13.0   10  12.0   13     14    14   76.0

# %%
df.loc[df["Name"].str.endswith('A')]
# Out:
#     Rno                          Name    CD  DAA    ML  CNS  PE-II  SSIS  \
# 0     1  VANKAYALA BALA SURYA KRISHNA  14.0   20  17.0    7     20    14
# 3     4                  NARRA VARSHA  12.0   17  10.3   17     20    19
# 5     6                AYENDLA SOWMYA  12.0   12  12.0   10     18    15
# 6     7        JAJAPURAM SAI CHANDANA  16.0   20  18.0   10     10     8
# 9    10          PABBA VAMSHI KRISHNA  13.0   19  16.0   14     14    14
# 10   11                  ARJUN SHARMA   9.0   13  11.0   15     12    14
# 11   12             SARIKONDA LEKHANA  15.0    8  12.0    9     14    12
# 12   13               GOGULA NAVATEJA  16.0   14  15.0   12     19    16
# 33   34              BAYYARAM MAANASA  19.0   15  17.0   12     14    13
# 34   35             SHENIGARAM SREEJA  15.0   17  16.0   19     19    19
# 37   38                PAGILLA ALEKYA  16.0   13  15.0   15     14    15
# 39   40              PENCHALA VEDHIKA  15.0   14  15.0   10      4     2
# ...

# %%
df.loc[df["Name"].str.contains('J')]
# Out:
#     Rno                        Name    CD  DAA    ML  CNS  PE-II  SSIS  Total
# 4     5  JONNALAGADDA MARUTHI TEJAS  12.0   20  16.0   13     10    12   83.0
# 6     7      JAJAPURAM SAI CHANDANA  16.0   20  18.0   10     10     8   82.0
# 10   11                ARJUN SHARMA   9.0   13  11.0   15     12    14   74.0
# 12   13             GOGULA NAVATEJA  16.0   14  15.0   12     19    16   92.0
# 15   16             GADDI SEERADWAJ   7.0    7   7.0   16     16    16   69.0
# 30   31     BANDARU VISWA TEJA GOUD  16.0   10  13.0   14     11    13   77.0
# 34   35           SHENIGARAM SREEJA  15.0   17  16.0   19     19    19  105.0
# 36   37         KHYATHI YAJJUVARAPU  14.0   12  13.0   13     15    14   81.0
# 40   41                GHANTE TEJAS  12.0   15  14.0   10     10    10   71.0
# 42   43                 MAJIGE ARUN   3.0    5   4.0   14     10    14   50.0
# 45   46         DHANAVATH DIVYA TEJ  10.0   10  10.0   15      8    12   65.0
# ...

# %%
df['Percentage']=0

# %%
df.head()
# Out:
#    Rno                          Name    CD  DAA    ML  CNS  PE-II  SSIS  \
# 0    1  VANKAYALA BALA SURYA KRISHNA  14.0   20  17.0    7     20    14
# 1    2    SANKARAMADDI HEMANTH REDDY  15.0   19  17.0   15     17    16
# 2    3                ADEPU SHASHANK  10.3   12  10.0    2     11     7
# 3    4                  NARRA VARSHA  12.0   17  10.3   17     20    19
# 4    5    JONNALAGADDA MARUTHI TEJAS  12.0   20  16.0   13     10    12
#
#    Total  Percentage
# 0   92.0           0
# 1   99.0           0
# 2   52.3           0
# 3   95.3           0
# 4   83.0           0

# %%
df["Percentage"]=(df["Total"]/120)*100

# %%
df.head()
# Out:
#    Rno                          Name    CD  DAA    ML  CNS  PE-II  SSIS  \
# 0    1  VANKAYALA BALA SURYA KRISHNA  14.0   20  17.0    7     20    14
# 1    2    SANKARAMADDI HEMANTH REDDY  15.0   19  17.0   15     17    16
# 2    3                ADEPU SHASHANK  10.3   12  10.0    2     11     7
# 3    4                  NARRA VARSHA  12.0   17  10.3   17     20    19
# 4    5    JONNALAGADDA MARUTHI TEJAS  12.0   20  16.0   13     10    12
#
#    Total  Percentage
# 0   92.0   76.666667
# 1   99.0   82.500000
# 2   52.3   43.583333
# 3   95.3   79.416667
# 4   83.0   69.166667

# %%
df["Result"]='PASS'

# %%
df.head()
# Out:
#    Rno                          Name    CD  DAA    ML  CNS  PE-II  SSIS  \
# 0    1  VANKAYALA BALA SURYA KRISHNA  14.0   20  17.0    7     20    14
# 1    2    SANKARAMADDI HEMANTH REDDY  15.0   19  17.0   15     17    16
# 2    3                ADEPU SHASHANK  10.3   12  10.0    2     11     7
# 3    4                  NARRA VARSHA  12.0   17  10.3   17     20    19
# 4    5    JONNALAGADDA MARUTHI TEJAS  12.0   20  16.0   13     10    12
#
#    Total  Percentage Result
# 0   92.0   76.666667   PASS
# 1   99.0   82.500000   PASS
# 2   52.3   43.583333   PASS
# 3   95.3   79.416667   PASS
# 4   83.0   69.166667   PASS

# %%
df.drop("Result",axis=1,inplace=True)

# %%
df.head()
# Out:
#    Rno                          Name    CD  DAA    ML  CNS  PE-II  SSIS  \
# 0    1  VANKAYALA BALA SURYA KRISHNA  14.0   20  17.0    7     20    14
# 1    2    SANKARAMADDI HEMANTH REDDY  15.0   19  17.0   15     17    16
# 2    3                ADEPU SHASHANK  10.3   12  10.0    2     11     7
# 3    4                  NARRA VARSHA  12.0   17  10.3   17     20    19
# 4    5    JONNALAGADDA MARUTHI TEJAS  12.0   20  16.0   13     10    12
#
#    Total  Percentage
# 0   92.0   76.666667
# 1   99.0   82.500000
# 2   52.3   43.583333
# 3   95.3   79.416667
# 4   83.0   69.166667

# %%
dff=pd.read_csv("marks_duplicate.csv")

# %%
dff.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 61    False
# 62    False
# 63    False
# 64    False
# 65    False
# Length: 66, dtype: bool

# %%
dff.duplicated().sum()
# Out:
# 0

# %%
dff.shape
# Out:
# (66, 8)

# %%
dff.drop_duplicates()
# Out:
#     Rno                          Name    CD   DAA    ML   CNS  PE-II  SSIS
# 0     1  VANKAYALA BALA SURYA KRISHNA  14.0  20.0  17.0   7.0   20.0  14.0
# 1     2    SANKARAMADDI HEMANTH REDDY  15.0  19.0  17.0  15.0   17.0  16.0
# 2     3                ADEPU SHASHANK  10.3  12.0  10.0   2.0   11.0   7.0
# 3     4                  NARRA VARSHA  12.0  17.0  10.3  17.0   20.0  19.0
# 4     5    JONNALAGADDA MARUTHI TEJAS  12.0  20.0  16.0  13.0   10.0  12.0
# ..  ...                           ...   ...   ...   ...   ...    ...   ...
# 61   62                 THOTA CHANDAN   8.0   7.0   8.0   9.0    7.0   8.0
# 62   63                NAGALLA LOHITH   9.0   9.0   9.0  12.0    8.0  10.0
# 63   64             GANAM GIRI PRASAD  12.0  12.0  12.0  12.0   14.0  13.0
# 64   65                    MOHD OSMAN   7.0  10.0   9.0   9.0    9.0   9.0
# 65   66                KATHERA VAMSHI   8.0  12.0  10.0  12.0    4.0   8.0
#
# [66 rows x 8 columns]

# %%
dff.shape
# Out:
# (66, 8)

# %%
dff.isna().sum()
# Out:
# Rno      0
# Name     0
# CD       0
# DAA      3
# ML       2
# CNS      4
# PE-II    1
# SSIS     3
# dtype: int64

# %%
dff.fillna(10,inplace=True)

# %%
dff.head()
# Out:
#    Rno                          Name    CD   DAA    ML   CNS  PE-II  SSIS
# 0    1  VANKAYALA BALA SURYA KRISHNA  14.0  20.0  17.0   7.0   20.0  14.0
# 1    2    SANKARAMADDI HEMANTH REDDY  15.0  19.0  17.0  15.0   17.0  16.0
# 2    3                ADEPU SHASHANK  10.3  12.0  10.0   2.0   11.0   7.0
# 3    4                  NARRA VARSHA  12.0  17.0  10.3  17.0   20.0  19.0
# 4    5    JONNALAGADDA MARUTHI TEJAS  12.0  20.0  16.0  13.0   10.0  12.0

# %%
df["Grade"]=0

# %%
df.head()
# Out:
#    Rno                          Name    CD  DAA    ML  CNS  PE-II  SSIS  \
# 0    1  VANKAYALA BALA SURYA KRISHNA  14.0   20  17.0    7     20    14
# 1    2    SANKARAMADDI HEMANTH REDDY  15.0   19  17.0   15     17    16
# 2    3                ADEPU SHASHANK  10.3   12  10.0    2     11     7
# 3    4                  NARRA VARSHA  12.0   17  10.3   17     20    19
# 4    5    JONNALAGADDA MARUTHI TEJAS  12.0   20  16.0   13     10    12
#
#    Total  Percentage  Grade
# 0   92.0   76.666667      0
# 1   99.0   82.500000      0
# 2   52.3   43.583333      0
# 3   95.3   79.416667      0
# 4   83.0   69.166667      0

# %%
if df["Percentage"]<40:
    df["Grade"]="Fail"
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6220\912155404.py in ?()
# ----> 1 if df["Percentage"]<40:
#       2     df["Grade"]="Fail"
#
# ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\generic.py in ?(self)
#    1517     @final
#    1518     def __nonzero__(self) -> NoReturn:
# -> 1519         raise ValueError(
#    1520             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1521             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1522         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
